# %% [markdown]
# # LISTAS DE EJEMPLOS

# %%
sexes = ["Male", "Female"]

zodiac_signs = ["Aries", "Taurus", "Gemini", "Cancer", "Leo", "Virgo", "Libra", "Scorpio", "Sagittarius", "Capricorn", "Aquarius", "Pisces"]

professions = [
    "Engineer", "Teacher", "Doctor", "Artist", "Developer", "Lawyer", "Nurse", 
    "Architect", "Scientist", "Chef", "Accountant", "Mechanic", "Pilot", 
    "Farmer", "Writer", "Designer", "Pharmacist", "Dentist", "Athlete", 
    "Entrepreneur", "Musician", "Veterinarian", "Surgeon", "Data Analyst", 
    "Psychologist", "Electrician", "Plumber", "Librarian", "Journalist", 
    "Social Worker", "Banker", "Consultant", "Biologist", "Astronomer", 
    "Mathematician", "Economist", "Chef de Cuisine", "Bartender", 
    "Web Developer", "Game Developer", "Content Creator", "Video Editor", 
    "Film Director", "Actor", "Producer", "Researcher", "Civil Servant", 
    "Policeman", "Firefighter", "Paramedic", "Translator", None
]

favorite_foods = [
    "Pizza", "Sushi", "Pasta", "Burger", "Salad", "Tacos", "Steak", "Ice Cream", "Soup",
    "Fried Rice", "Sandwich", "Lasagna", "Ramen", "Dumplings", "Barbecue", "Pho", "Curry", 
    "Burrito", "Bagel", "Pancakes", "Waffles", "Seafood", "Hot Dog", "Chili", "Fajitas", 
    "Shawarma", "Gnocchi", "Falafel", "Empanadas", "Cheesecake", "Crepes", "Paella", 
    "Mac and Cheese", "Chow Mein", "Spring Rolls", "Miso Soup", "Biryani", "Lamb Chops", 
    "Stuffed Peppers", "Clam Chowder", "Spaghetti", "Meatballs", "Grilled Cheese", 
    "Quesadillas", "Potato Salad", "Risotto", "Onion Rings", "Chicken Wings", "Tamales", 
    "Cannoli", "Eclairs", None
]

favorite_sports = [
    "Soccer", "Basketball", "Tennis", "Cricket", "Swimming", "Running", "Cycling", "Baseball", 
    "Volleyball", "Hockey", "Table Tennis", "Badminton", "Rugby", "Golf", "Skating", "Skiing", 
    "Snowboarding", "Surfing", "Boxing", "Wrestling", "Martial Arts", "Darts", "Archery", 
    "Fencing", "Rowing", "Canoeing", "Shooting", "Judo", "Taekwondo", "Karate", "Triathlon", 
    "Ice Hockey", "Figure Skating", "Parkour", "Climbing", "Bowling", "Squash", "Snooker", 
    "Lacrosse", "Kitesurfing", "Skateboarding", "Weightlifting", "Polo", "Handball", 
    "Equestrian", "Bobsleigh", "Curling", "Paragliding", "Speed Skating", None
]

movie_genres = [
    "Action", "Comedy", "Drama", "Horror", "Romance", "Sci-Fi", "Documentary", "Fantasy", 
    "Thriller", "Mystery", "Adventure", "Musical", "Animation", "Historical", "Biography", 
    "Crime", "War", "Western", "Sport", "Family", "Superhero", "Noir", "Parody", "Satire", 
    "Political", "Psychological", "Erotic", "Silent Film", "Independent", "Experimental", 
    "Epic", "Disaster", "Road Movie", "Spy", "Heist", "Mockumentary", "Period Piece", 
    "Romantic Comedy", "Slasher", "Dark Comedy", "Suspense", "Fantasy Romance", 
    "Coming-of-Age", "Teen Drama", "Courtroom Drama", "Zombie", "Cyberpunk", "Steampunk", 
    "Magical Realism", None
]

animals = [
    "Dog", "Cat", "Bird", "Horse", "Rabbit", "Fish", "Lion", "Tiger", "Elephant", "Dolphin", 
    "Panda", "Kangaroo", "Monkey", "Wolf", "Fox", "Bear", "Owl", "Penguin", "Koala", "Giraffe", 
    "Zebra", "Cheetah", "Crocodile", "Leopard", "Turtle", "Frog", "Snake", "Hamster", "Parrot", 
    "Lizard", "Deer", "Hedgehog", "Antelope", "Peacock", "Seal", "Otter", "Swan", "Flamingo", 
    "Bat", "Shark", "Whale", "Octopus", "Jellyfish", "Cobra", "Buffalo", "Moose", "Donkey", 
    "Sheep", "Goat", "Chimpanzee", "Starfish", None
]

languages = [
    "English", "Spanish", "French", "German", "Chinese", "Japanese", "Russian", "Arabic", 
    "Portuguese", "Korean", "Italian", "Hindi", "Turkish", "Dutch", "Greek", "Swedish", 
    "Norwegian", "Finnish", "Polish", "Czech", "Thai", "Vietnamese", "Hungarian", "Danish", 
    "Hebrew", "Malay", "Indonesian", "Filipino", "Swahili", "Zulu", "Icelandic", "Irish", 
    "Welsh", "Slovak", "Estonian", "Latvian", "Lithuanian", "Ukrainian", "Serbian", "Croatian", 
    "Slovenian", "Romanian", "Bulgarian", "Georgian", "Kazakh", "Uzbek", "Tibetan", "Pashto", 
    "Farsi", "Tamil", None
]

hobbies = [
    "Reading", "Traveling", "Gardening", "Cooking", "Gaming", "Fishing", "Painting", "Photography", 
    "Dancing", "Knitting", "Hiking", "Cycling", "Yoga", "Playing Instruments", "Drawing", "Bird Watching", 
    "Writing", "Pottery", "Woodworking", "Fitness", "Meditation", "Collecting Stamps", "Origami", 
    "Calligraphy", "Scrapbooking", "Model Building", "Astronomy", "Puzzle Solving", "Chess", 
    "Board Games", "Video Games", "Scuba Diving", "Snorkeling", "Rock Climbing", "Metal Detecting", 
    "RC Cars", "Wine Tasting", "Brewing", "Home Renovation", "Camping", "Canoeing", "Kayaking", 
    "Martial Arts", "Geocaching", "Volunteering", "Language", "Stargazing", "Antiquing", 
    "Playing Cards", "Learning",None
]

tv_shows = [
    "Breaking Bad", "Game of Thrones", "Friends", "The Office", "Stranger Things", 
    "The Crown", "The Witcher", "The Mandalorian", "Sherlock", "The Big Bang Theory", 
    "Parks and Recreation", "Better Call Saul", "Black Mirror", "Westworld", "Dexter", 
    "Brooklyn Nine-Nine", "The Simpsons", "South Park", "Fargo", "Mad Men", 
    "True Detective", "How I Met Your Mother", "The Walking Dead", "Narcos", 
    "Succession", "The Boys", "The Sopranos", "House of Cards", "Ozark", 
    "Lucifer", "Peaky Blinders", "Vikings", "The Umbrella Academy", "Supernatural", 
    "Arrow", "Gotham", "The Flash", "Doctor Who", "Euphoria", 
    "Homeland", "Downton Abbey", "Schitt's Creek", "The Good Place", "This Is Us", 
    "Grey's Anatomy", "CSI", "NCIS", "The Twilight Zone", "Buffy the Vampire Slayer", None
]

colors = [
    "Red", "Blue", "Green", "Yellow", "Purple", "Black", "White", "Orange", "Pink", "Brown", 
    "Gray", "Gold", "Silver", "Cyan", "Magenta", "Teal", "Indigo", "Lime", "Turquoise", "Beige", 
    "Scarlet", "Amber", "Peach", "Lavender", "Maroon", "Aqua", "Ivory", "Crimson", "Charcoal", 
    "Emerald", "Fuchsia", "Salmon", "Bronze", "Mint", "Rose", "Ochre", "Ruby", "Lilac", 
    "Plum", "Amethyst", "Topaz", "Chartreuse", "Chocolate", "Navy", "Jade", "Scarlet", 
    "Sapphire", "Periwinkle", "Azure", "Coral", None
]

drinks = [
    "Coffee", "Tea", "Soda", "Water", "Wine", "Beer", "Juice", "Milk", "Smoothie", "Cocktail", 
    "Milkshake", "Hot Chocolate", "Lemonade", "Sparkling Water", "Energy Drink", "Iced Tea", 
    "Espresso", "Latte", "Cider", "Herbal Tea", "Kombucha", "Matcha", "Mocha", "Americano", 
    "Chai", "Green Tea", "Black Tea", "Oolong Tea", "White Tea", "Chamomile Tea", "Margarita", 
    "Bloody Mary", "Mimosa", "Gin and Tonic", "Whiskey Sour", "Rum and Coke", "Old Fashioned", 
    "Piña Colada", "Daiquiri", "Mai Tai", "Sangria", "Shirley Temple", "Root Beer", "Tonic Water", 
    "Ginger Ale", "Smoothie Bowl", "Ice Blended Coffee", "Cold Brew", "Nitro Coffee", None
]

music_genres = [
    "Pop", "Rock", "Jazz", "Classical", "Hip-Hop", "Electronic", "Blues", "R&B", "Reggae", 
    "Country", "Funk", "Soul", "Metal", "Punk", "Folk", "Disco", "Gospel", "Opera", 
    "K-Pop", "Latin", "Trap", "Indie", "House", "Trance", "EDM", "Dubstep", "Ambient", 
    "Lo-fi", "Ska", "Grunge", "Alternative Rock", "Dance", "Techno", "Samba", "Bossa Nova", 
    "Flamenco", "Tango", "Cumbia", "Bolero", "Chillwave", "Experimental", "New Age", 
    "Synthwave", "Chiptune", "Hardcore", "Post-Rock", "Shoegaze", "World Music", "Afrobeats", 
    "Zouk", "Highlife", None
]

technologies = [
    "AI", "Blockchain", "IoT", "Cloud Computing", "Big Data", "5G", "VR", "AR", "Machine Learning", 
    "Quantum Computing", "Cybersecurity", "Edge Computing", "Automation", "Drones", "Robotics", 
    "Wearables", "3D Printing", "Nanotechnology", "Digital Twins", "Open Source", "DevOps", 
    "Agile Methodologies", "Microservices", "Containers", "Serverless Computing", "Green Computing", 
    "Augmented Analytics", "Data Lakes", "Data Warehousing", "Bioinformatics", "Clean Energy Tech", 
    "Smart Cities", "Cryptocurrency", "Digital Health", "Autonomous Vehicles", "Spatial Computing", 
    "Natural Language Processing", "Computer Vision", "Augmented Reality", "Energy Harvesting", 
    "Brain-Computer Interfaces", "Digital Farming", "Personalized Medicine", "Privacy-Preserving Tech", 
    "Edge AI", "Synthetic Data", "Knowledge Graphs", "Web 3.0", "Metaverse", "Zero Trust Security", None
]

cars = [
    "Toyota", "Honda", "Ford", "Chevrolet", "BMW", "Mercedes-Benz", "Audi", "Volkswagen", 
    "Porsche", "Tesla", "Ferrari", "Lamborghini", "Hyundai", "Kia", "Nissan", "Subaru", 
    "Mazda", "Jaguar", "Land Rover", "Volvo", "Jeep", "Dodge", "Chrysler", "Buick", 
    "Acura", "Infiniti", "Lexus", "Mitsubishi", "Mini", "Peugeot", "Citroën", "Renault", 
    "Alfa Romeo", "Fiat", "Skoda", "SEAT", "Opel", "Suzuki", "Isuzu", "Saab", "Bugatti", 
    "Maserati", "Bentley", "Rolls-Royce", "Aston Martin", "McLaren", "Pagani", "Rimac", 
    "Koenigsegg", "SsangYong", None
]

# %% [markdown]
# # FUNCION GENERADORA

# %%
import random
from faker import Faker

fake = Faker()

def generate_fake_data(records):
    for _ in range(records):
        yield {
            "email": fake.email(),
            "address": fake.address(),
            "country": fake.country(),
            "sex": random.choice(sexes),
            "age": random.randint(18, 99),
            "profession": random.choice(professions),
            "zodiac_sign": random.choice(zodiac_signs),
            "favorite_food": random.choice(favorite_foods),
            "favorite_sport": random.choice(favorite_sports),
            "favorite_movie_genre": random.choice(movie_genres),
            "favorite_animal": random.choice(animals),
            "preferred_language": random.choice(languages),
            "hobby": random.choice(hobbies),
            "favorite_tv_show": random.choice(tv_shows),
            "favorite_color": random.choice(colors),
            "favorite_drink": random.choice(drinks),
            "favorite_music": random.choice(music_genres),
            "favorite_technology": random.choice(technologies),
            "favorite_car": random.choice(cars),
        }

# %% [markdown]
# # DEFINIR PARAMETROS

# %%
# Configuraciones
db_name = "bulk.db"
json_file = "bulk_data.json"
records_to_generate = 5_000_000  # Número de registros a generar
batch_size = 10_000  # Tamaño de lotes para inserciones o escritura en JSON

# %% [markdown]
# # FUNCIONES

# %%
import sqlite3
import os
import json
import os
import math
import pandas as pd

def save_to_sqlite_with_generator(data_generator, total_records, db_name, batch_size=10_000, directory="/sqlite_database"):
    """
    Guarda los datos generados en una base de datos SQLite en lotes, usando un generador para manejar grandes volúmenes de datos.

    Args:
        data_generator (generator): Generador que produce los datos.
        total_records (int): Número total de registros a generar.
        db_name (str): Nombre de la base de datos SQLite.
        batch_size (int): Número de registros por lote.
        directory (str): Directorio donde guardar la base de datos.
    """
    # Crear el directorio si no existe
    os.makedirs(directory, exist_ok=True)
    db_path = os.path.join(directory, db_name)

    # Verificar si el archivo de la base de datos existe y eliminarlo si es necesario
    if os.path.exists(db_path):
        os.remove(db_path)
        print(f"La base de datos '{db_path}' ha sido eliminada.")
    
    # Crear conexión SQLite y tabla
    try:
        conn = sqlite3.connect(db_path)
    except sqlite3.OperationalError as e:
        print(f"Error al conectar con la base de datos: {e}")
        return

    cursor = conn.cursor()
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS large_table (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        email TEXT,
        address TEXT,
        country TEXT,
        sex TEXT,
        age INTEGER,
        profession TEXT,
        zodiac_sign TEXT,
        favorite_food TEXT,
        favorite_sport TEXT,
        favorite_movie_genre TEXT,
        favorite_animal TEXT,
        preferred_language TEXT,
        hobby TEXT,
        favorite_tv_show TEXT,
        favorite_color TEXT,
        favorite_drink TEXT,
        favorite_music TEXT,
        favorite_technology TEXT,
        favorite_car TEXT
    )
    """)
    conn.commit()

    # Insertar datos en lotes
    batch = []
    for i, record in enumerate(data_generator, start=1):
        batch.append(record)
        if len(batch) == batch_size or i == total_records:
            cursor.executemany(
                """
                INSERT INTO large_table (
                    email, address, country, sex, age, profession, zodiac_sign, favorite_food, 
                    favorite_sport, favorite_movie_genre, favorite_animal, preferred_language,
                    hobby, favorite_tv_show, favorite_color, favorite_drink, favorite_music, 
                    favorite_technology, favorite_car
                ) VALUES (
                    :email, :address, :country, :sex, :age, :profession, :zodiac_sign, 
                    :favorite_food, :favorite_sport, :favorite_movie_genre, :favorite_animal, 
                    :preferred_language, :hobby, :favorite_tv_show, :favorite_color,
                    :favorite_drink, :favorite_music, :favorite_technology, :favorite_car
                )
                """,
                batch
            )
            conn.commit()
            print(f"Batch {i // batch_size + 1} insertado.")
            batch = []

    conn.close()
    print(f"Datos guardados en la base de datos '{db_path}'.")

def save_to_csv_with_generator(data_generator, total_records, num_files, csv_file_prefix="bulk_data", directory="./csv_files"):
    os.makedirs(directory, exist_ok=True)
    batch_size = math.ceil(total_records / num_files)

    for file_index in range(num_files):
        file_path = os.path.join(directory, f"{csv_file_prefix}_{file_index + 1}.csv")
        batch = [next(data_generator) for _ in range(min(batch_size, total_records - file_index * batch_size))]
        df = pd.DataFrame(batch)
        df.to_csv(file_path, sep=";", index=False)
        print(f"Datos guardados en el archivo CSV '{file_path}' > {file_index + 1} de {num_files}.")


def save_to_json_with_generator(data_generator, total_records, num_files, json_file_prefix="bulk_data", directory="./json_files"):
    os.makedirs(directory, exist_ok=True)
    batch_size = math.ceil(total_records / num_files)

    for file_index in range(num_files):
        file_path = os.path.join(directory, f"{json_file_prefix}_{file_index + 1}.json")
        batch = [next(data_generator) for _ in range(min(batch_size, total_records - file_index * batch_size))]
        with open(file_path, "w", encoding="utf-8") as json_file:
            json.dump(batch, json_file, indent=4)
        print(f"Datos guardados en el archivo JSON '{file_path}' > {file_index + 1} de {num_files}.")

def save_to_parquet_with_generator(data_generator, total_records, num_files, parquet_file_prefix="bulk_data", directory="./parquet_files"):
    os.makedirs(directory, exist_ok=True)
    batch_size = math.ceil(total_records / num_files)

    for file_index in range(num_files):
        file_path = os.path.join(directory, f"{parquet_file_prefix}_{file_index + 1}.parquet")
        batch = [next(data_generator) for _ in range(min(batch_size, total_records - file_index * batch_size))]
        df = pd.DataFrame(batch)
        df.to_parquet(file_path, index=False)
        print(f"Datos guardados en el archivo Parquet '{file_path}' > {file_index + 1} de {num_files}.")

# %% [markdown]
# # DEFINIR PARAMETROS

# %%
# Configuraciones
db_name = "bulk.db"
json_file = "bulk_data.json"
total_records = 5_000_000  # Número de registros a generar
batch_size = 10_000  # Tamaño de lotes para inserciones o escritura en JSON
total_files = 20

# %% [markdown]
# # GUARDAR DATOS EN PARQUET

# %%
# %%time

save_to_parquet_with_generator(
    data_generator=generate_fake_data(total_records),
    total_records=total_records,
    num_files=total_files
)
# Out:
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_1.parquet' > 0 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_2.parquet' > 1 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_3.parquet' > 2 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_4.parquet' > 3 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_5.parquet' > 4 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_6.parquet' > 5 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_7.parquet' > 6 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_8.parquet' > 7 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_9.parquet' > 8 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_10.parquet' > 9 de 20.
# Datos guardados en el archivo Parquet './parquet_files/bulk_data_11.parquet' > 10 de 20.
# ...

# %% [markdown]
# # GUARDAR DATOS EN JSON

# %%
# %%time

save_to_json_with_generator(
    data_generator=generate_fake_data(total_records),
    total_records=total_records,
    num_files=total_files
)

# %% [markdown]
# # GUARDAR DATOS EN CSV

# %%
# %%time

save_to_csv_with_generator(
    data_generator=generate_fake_data(total_records),
    total_records=total_records,
    num_files=total_files
)

# %% [markdown]
# # GUARDAR SQLite

# %%
# %%time

save_to_sqlite_with_generator(
    data_generator=generate_fake_data(total_records),
    total_records=total_records,
    db_name=db_name,
    batch_size=batch_size
)
# Out:
# La base de datos '/sqlite_database/bulk.db' ha sido eliminada.
# Batch 2 insertado.
# Batch 3 insertado.
# Batch 4 insertado.
# Batch 5 insertado.
# Batch 6 insertado.
# Batch 7 insertado.
# Batch 8 insertado.
# Batch 9 insertado.
# Batch 10 insertado.
# Batch 11 insertado.
# Batch 12 insertado.
# Batch 13 insertado.
# Batch 14 insertado.
# Batch 15 insertado.
# Batch 16 insertado.
# Batch 17 insertado.
# Batch 18 insertado.
# Batch 19 insertado.
# Batch 20 insertado.
# Batch 21 insertado.
# Batch 22 insertado.
# Batch 23 insertado.
# Batch 24 insertado.
# Batch 25 insertado.
# Batch 26 insertado.
# Batch 27 insertado.
# Batch 28 insertado.
# Batch 29 insertado.
# Batch 30 insertado.
# Batch 31 insertado.
# Batch 32 insertado.
# Batch 33 insertado.
# Batch 34 insertado.
# Batch 35 insertado.
# Batch 36 insertado.
# Batch 37 insertado.
# Batch 38 insertado.
# Batch 39 insertado.
# Batch 40 insertado.
# Batch 41 insertado.
# Batch 42 insertado.
# Batch 43 insertado.
# ...
